# %% [markdown]
# # Ejercicio 1
# * a) ¿Cuántas filas tiene el Dataset? 5 filas
# * b) ¿Cuántas columnas tiene el Dataset? 16 columnas
# * c) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘size_bytes’? 3
# * d) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘currency’? 4
# * e) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘price? 5

# %% [markdown]
# <table> <tr> <th></th> <th>id</th> <th>track_name</th> <th>size_bytes</th> <th>currency</th> <th>price</th> <th>rating_count_tot</th> <th>rating_count_ver</th> <th>user_rating</th> <th>user_rating_ver</th> <th>ver</th> <th>cont_rating</th> <th>prime_genre</th> <th>sup_devices.num</th> <th>ipadSc_urls.num</th> <th>lang.num</th> <th>vpp_lic</th> </tr> <tr> <td>1</td> <td>281656475</td> <td>PAC-MAN Premium</td> <td>100788224</td> <td>USD</td> <td>3.99</td> <td>21292</td> <td>26</td> <td>4</td> <td>4.5</td> <td>6.3.5</td> <td>4+</td> <td>Games</td> <td>38</td> <td>5</td> <td>10</td> <td>1</td> </tr> <tr> <td>2</td> <td>281796108</td> <td>Evernote - stay organized</td> <td>158578688</td> <td>USD</td> <td>0</td> <td>161065</td> <td>26</td> <td>4</td> <td>3.5</td> <td>8.2.2</td> <td>4+</td> <td>Productivity</td> <td>37</td> <td>5</td> <td>23</td> <td>1</td> </tr> <tr> <td>3</td> <td>281940292</td> <td>WeatherBug - Local Weather, Radar, Maps, Alerts</td> <td>100524032</td> <td>USD</td> <td>0</td> <td>188583</td> <td>2822</td> <td>3.5</td> <td>4.5</td> <td>5.0.0</td> <td>4+</td> <td>Weather</td> <td>37</td> <td>5</td> <td>3</td> <td>1</td> </tr> <tr> <td>4</td> <td>282614216</td> <td>eBay: Best App to Buy, Sell, Save! Online Shopping</td> <td>128512000</td> <td>USD</td> <td>0</td> <td>262241</td> <td>649</td> <td>4</td> <td>4.5</td> <td>5.10.0</td> <td>12+</td> <td>Shopping</td> <td>37</td> <td>5</td> <td>9</td> <td>1</td> </tr> </table>

# %% [markdown]
# # Ejercicio 2
# Trabaja con la columna ‘track_name’ y contesta los siguientes planteamientos.
# * a) ¿Cuántos caracteres tiene el nombre de aplicación más largo y cuál es el nombre? eBay: Best App to Buy, Sell, Save! Online Shopping = 47 caracteres
# * b) ¿Cuántos caracteres tiene el nombre de aplicación más corto y cuál es el nombre? PAC-MAN Premium = 14 caracteres
# * c) ¿Cuál es número promedio de caracteres que tiene el nombre de una aplicación en este Dataset? 31.75
# * d) ¿Cuál es la varianza y la desviación estándar en el número de caracteres que conforman el nombre de una aplicación en este Dataset? Varianza = 250.416667 La desviación estándar es de: 15.837656
# * e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Numero de caracteres’.
# • Título del histograma ‘Nombres de aplicación’.

# %% [markdown]
# # Ejercicio 3
# ## Trabaja con la columna ‘size_bytes’ y contesta los siguientes planteamientos.
# * a) ¿Cuántos bytes tiene la aplicación más “pesada”? Evernote - stay organized
# * b) ¿Cuántos bytes tiene la aplicación más “liviana”? WeatherBug - Local Weather, Radar, Maps, Alerts
# * c) ¿Cuál peso promedio en bytes de una aplicación en este Dataset? el promedio es de 132248836
# * d) ¿Cuál es la varianza y la desviación estándar del peso en bytes de una aplicación en este Dataset? su varianza es: 67025621767601.333333 su desviacion estandar es de: 2581652.416933
# * e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Peso en bytes’.
# • Título del histograma ‘Peso de las aplicaciones’.

# %% [markdown]
# # Ejercicio 4
# Trabaja con la columna ‘user_rating’ y contesta los siguientes planteamientos.
# * a) ¿Cuál es el valor más alto de valoración?
# * b) ¿ Cuál es el valor más bajo de valoración?
# * c) ¿Cuál es el promedio de valoración de una aplicación en este Dataset?
# * d) ¿Cuál es la varianza y la desviación estándar de valoración de una aplicación en este Dataset?
# * e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Valoración’.
# • Título del histograma ‘Valoración de las aplicaciones’.
