# %% [markdown]
# # Ejercicio 1
# * a) ¿Cuántas filas tiene el Dataset? 5 filas
# * b) ¿Cuántas columnas tiene el Dataset? 5 columnas
# * c) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘size_bytes’? 4
# * d) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘currency’? 3
# * e) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘price? 2

# %% [markdown]
# # Ejercicio 2
# Trabaja con la columna ‘track_name’ y contesta los siguientes planteamientos.
# * a) ¿Cuántos caracteres tiene el nombre de aplicación más largo y cuál es el nombre? 21 Minecraft: Pocket Edition
# * b) ¿Cuántos caracteres tiene el nombre de aplicación más corto y cuál es el nombre? 8 Facebook
# * c) ¿Cuál es número promedio de caracteres que tiene el nombre de una aplicación en este Dataset? 13.8
# * d) ¿Cuál es la varianza y la desviación estándar en el número de caracteres que conforman el nombre de una aplicación en este Dataset? varianza de 33.2, desviasion estandar de 5.76
# * e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Numero de caracteres’.
# • Título del histograma ‘Nombres de aplicación’.

# %% [markdown]
# # Ejercicio 3
# ## Trabaja con la columna ‘size_bytes’ y contesta los siguientes planteamientos.
# * a) ¿Cuántos bytes tiene la aplicación más “pesada”?
# * b) ¿Cuántos bytes tiene la aplicación más “liviana”?
# * c) ¿Cuál peso promedio en bytes de una aplicación en este Dataset?
# * d) ¿Cuál es la varianza y la desviación estándar del peso en bytes de una aplicación en este Dataset?
# * e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Peso en bytes’.
# • Título del histograma ‘Peso de las aplicaciones’.

# %% [markdown]
# # Ejercicio 4
# Trabaja con la columna ‘user_rating’ y contesta los siguientes planteamientos.
# * a) ¿Cuál es el valor más alto de valoración?
# * b) ¿ Cuál es el valor más bajo de valoración?
# * c) ¿Cuál es el promedio de valoración de una aplicación en este Dataset?
# * d) ¿Cuál es la varianza y la desviación estándar de valoración de una aplicación en este Dataset?
# * e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Valoración’.
# • Título del histograma ‘Valoración de las aplicaciones’.
